# %%
import pandas as pd
from plotnine import *

# %%
station = pd.read_csv('/root/data-science-hw/data/stations.csv')
station[:10]
# Out:
#                                station   type  count       time        lat  \
# 0           Washington Blvd & 7th St N  Leave      2   LATEMORN  38.880834
# 1           Washington Blvd & 7th St N  Leave      2  AFTERNOON  38.880834
# 2  1st & Washington Hospital Center NW  Leave      7    EVENING  38.928743
# 3  1st & Washington Hospital Center NW  Leave      1   LATEMORN  38.928743
# 4  1st & Washington Hospital Center NW  Leave      1      NIGHT  38.928743
# 5                       19th & K St NW  Leave     12    EVENING  38.902204
# 6                       19th & K St NW  Leave      4   LATEMORN  38.902204
# 7                       19th & K St NW  Leave      7  AFTERNOON  38.902204
# 8                       19th & K St NW  Leave      4      NIGHT  38.902204
# 9        Potomac & Pennsylvania Ave SE  Leave      5    EVENING  38.880300
#
#         long
# 0 -77.091129
# 1 -77.091129
# 2 -77.012457
# 3 -77.012457
# 4 -77.012457
# 5 -77.043370
# 6 -77.043370
# 7 -77.043370
# ...

# %%
(ggplot(station)
 + facet_grid(facets="type ~ time")
 + aes(x='long',y='lat')
 + geom_point()
)
# Out:
# <ggplot: (8778800395939)>
