# %%
import pandas as pd
from plotnine import *
                                                                               
weather=pd.read_csv("https://raw.githubusercontent.com/alanjones2/dataviz/master/london2018.csv")                                                          
   
weather
# Out:
#     Year  Month  Tmax  Tmin  Rain    Sun
# 0   2018      1   9.7   3.8  58.0   46.5
# 1   2018      2   6.7   0.6  29.0   92.0
# 2   2018      3   9.8   3.0  81.2   70.3
# 3   2018      4  15.5   7.9  65.2  113.4
# 4   2018      5  20.8   9.8  58.4  248.3
# 5   2018      6  24.2  13.1   0.4  234.5
# 6   2018      7  28.3  16.4  14.8  272.5
# 7   2018      8  24.5  14.5  48.2  182.1
# 8   2018      9  20.9  11.0  29.4  195.0
# 9   2018     10  16.5   8.5  61.0  137.0
# 10  2018     11  12.2   5.8  73.8   72.9
# 11  2018     12  10.7   5.2  60.6   40.3

# %%
(ggplot(weather,aes('Month', 'Tmax'))
    + geom_line()
)
# Out:
# <ggplot: (8748068600923)>

# %%
# make the months as integers no floats (i.e: 2.5, 12.5)
months = weather['Month']

(ggplot(weather,aes('Month', 'Tmax'))
    + geom_line()
    + scale_x_continuous(breaks=months)
)
# Out:
# <ggplot: (8748074116578)>

# %%
# labeling months
month_labels=("Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec")
(ggplot(weather,aes('Month','Tmax')) 
  + geom_line(color='red') 
  + scale_x_continuous(breaks=months,labels=month_labels) 
)
# Out:
# <ggplot: (8748068309613)>

# %%
# column chart
(ggplot(weather,aes('Month','Tmax'))
  + geom_col(fill='red')
  + scale_x_continuous(breaks=months, labels=month_labels)
  + theme_light()
)
# Out:
# <ggplot: (8748068212926)>

# %%
(ggplot(weather,aes('Month','Rain'))
  + geom_col(fill='green')
  + scale_x_continuous(breaks=months, labels=month_labels)
  + theme_light()
)
# Out:
# <ggplot: (8748068161976)>

# %%
demo_dic = {'x': [25, 0, 75, 200], 'y': [11, 0, 53, 300], 'Shape': ['circle', 'circle', 'square', 'square']}

demo = pd.DataFrame(demo_dic)
demo
# Out:
#      x    y   Shape
# 0   25   11  circle
# 1    0    0  circle
# 2   75   53  square
# 3  200  300  square

# %%
(ggplot(demo,
aes(color='Shape', y='y', x='x')) 
 + geom_point())
# Out:
# <ggplot: (8748070887304)>

# %%
(ggplot(demo, aes(color='Shape', y='y', x='x')) 
 + geom_bar(stat="identity")
)
# Out:
# <ggplot: (8748066578860)>
